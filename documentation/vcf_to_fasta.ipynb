# %% [markdown]
# # VCF to FASTA
#
# A robust Python pipeline for applying VCF variants to FASTA reference sequences with comprehensive validation.
#
# ## Overview
# This pipeline reads a reference FASTA file and a VCF file, applies all variants to the reference sequence, validates the changes, and outputs a new FASTA file with the mutations applied.
#
# ### Examples
#
# Lets start by importing library

# %%
import sys

sys.path.append("/workspace")
from src.vcf import VCFtoFASTAPipeline

# %% [markdown]
# Now lets define our inputs and outputs

# %%
fasta_path = "/workspace/datasets/haploid/fasta/04245.denovo.fasta"
vcf_path = "/workspace/datasets/haploid/vcf/STR40.high_confidence.vcf"
output_dir = "/workspace/datasets/haploid/fasta/STR40.fasta"
log_dir = "/workspace/datasets/haploid/logs/STR40.vcftofasta.pipeline.log"

# %%
pipeline = VCFtoFASTAPipeline(
    fasta_path=fasta_path,
    vcf_path=vcf_path,
    output_path=output_dir,
    log_file=log_dir,
)

# %%
validation_passed = pipeline.run()
# Out:
# [2026-01-09 01:20:19] ============================================================
# [2026-01-09 01:20:19] VCF to FASTA Pipeline
# [2026-01-09 01:20:19] ============================================================
# [2026-01-09 01:20:19] Input FASTA: /workspace/datasets/haploid/fasta/04245.denovo.fasta
# [2026-01-09 01:20:19] Input VCF: /workspace/datasets/haploid/vcf/STR40.high_confidence.vcf
# [2026-01-09 01:20:19] Output FASTA: /workspace/datasets/haploid/fasta/STR40.fasta
# [2026-01-09 01:20:19] Log file: /workspace/datasets/haploid/logs/STR40.vcftofasta.pipeline.log
# [2026-01-09 01:20:19] ============================================================
#
# [2026-01-09 01:20:19] Checking dependencies...
# [2026-01-09 01:20:19] ✓ bcftools found
# [2026-01-09 01:20:19] ✓ samtools found
# [2026-01-09 01:20:19] ✓ bgzip found
# [2026-01-09 01:20:19] ✓ tabix found
# [2026-01-09 01:20:19] FASTA index already exists: /workspace/datasets/haploid/fasta/04245.denovo.fasta.fai
# [2026-01-09 01:20:19] Compressed VCF already exists: /workspace/datasets/haploid/vcf/STR40.high_confidence.vcf.gz
# [2026-01-09 01:20:19] VCF index already exists: /workspace/datasets/haploid/vcf/STR40.high_confidence.vcf.gz.tbi
# [2026-01-09 01:20:19]
# Number of variants in VCF: 17
# [2026-01-09 01:20:19] Applying variants to reference...
# [2026-01-09 01:20:19] bcftools stderr: Note: the --sample option not given, applying all records regardless of the genotype
# Applied 17 variants
#
# [2026-01-09 01:20:19]
# ============================================================
# [2026-01-09 01:20:19] VALIDATION REPORT
# [2026-01-09 01:20:19] ============================================================
# [2026-01-09 01:20:19]
# Input FASTA statistics:
# [2026-01-09 01:20:19]   Number of sequences: 6
# [2026-01-09 01:20:19]   Total length: 9,424,047 bp
# [2026-01-09 01:20:19]   MD5 checksum: b9cee39a8f09442812e931e696db77f2
# [2026-01-09 01:20:19]
# Output FASTA statistics:
# [2026-01-09 01:20:20]   Number of sequences: 6
# [2026-01-09 01:20:20]   Total length: 9,424,054 bp
# [2026-01-09 01:20:20]   MD5 checksum: 484605b344acf1b1faab28a340ec18b0
# [2026-01-09 01:20:20]
# Validation checks:
# [2026-01-09 01:20:20]   ✓ Number of sequences matches
# [2026-01-09 01:20:20]   ✓ Output differs from input (variants applied)
# [2026-01-09 01:20:20]   ✓ Output file exists and has content
# [2026-01-09 01:20:20]
#   Length change: +7 bp
# [2026-01-09 01:20:20]
# ============================================================
# [2026-01-09 01:20:20] ✓ VALIDATION PASSED
# [2026-01-09 01:20:20] ============================================================
#
# [2026-01-09 01:20:20]
# Pipeline completed successfully!
# [2026-01-09 01:20:20] Output saved to: /workspace/datasets/haploid/fasta/STR40.fasta

# %% [markdown]
# Great, looks like we successfully asembled the genome using the reference fasta and the vcf variant file.  Lets do another example to load up multiple files.

# %%
fasta_path = "/workspace/datasets/haploid/fasta/04245.denovo.fasta"

strains = ["STR134", "STR267", "STR286"]

for strain in strains:
    vcf_path = f"/workspace/datasets/haploid/vcf/{strain}.high_confidence.vcf"
    output_dir = f"/workspace/datasets/haploid/fasta/{strain}.fasta"
    log_dir = f"/workspace/datasets/haploid/logs/{strain}.vcftofasta.pipeline.log"

    pipeline = VCFtoFASTAPipeline(
        fasta_path=fasta_path,
        vcf_path=vcf_path,
        output_path=output_dir,
        log_file=log_dir,
    )
    validation_passed = pipeline.run()
# Out:
# [2026-01-09 01:20:20] ============================================================
# [2026-01-09 01:20:20] VCF to FASTA Pipeline
# [2026-01-09 01:20:20] ============================================================
# [2026-01-09 01:20:20] Input FASTA: /workspace/datasets/haploid/fasta/04245.denovo.fasta
# [2026-01-09 01:20:20] Input VCF: /workspace/datasets/haploid/vcf/STR134.high_confidence.vcf
# [2026-01-09 01:20:20] Output FASTA: /workspace/datasets/haploid/fasta/STR134.fasta
# [2026-01-09 01:20:20] Log file: /workspace/datasets/haploid/logs/STR134.vcftofasta.pipeline.log
# [2026-01-09 01:20:20] ============================================================
#
# [2026-01-09 01:20:20] Checking dependencies...
# [2026-01-09 01:20:20] ✓ bcftools found
# [2026-01-09 01:20:20] ✓ samtools found
# [2026-01-09 01:20:20] ✓ bgzip found
# [2026-01-09 01:20:20] ✓ tabix found
# [2026-01-09 01:20:20] FASTA index already exists: /workspace/datasets/haploid/fasta/04245.denovo.fasta.fai
# [2026-01-09 01:20:20] Compressing VCF file...
# [2026-01-09 01:20:20] Command: bgzip -c /workspace/datasets/haploid/vcf/STR134.high_confidence.vcf > /workspace/datasets/haploid/vcf/STR134.high_confidence.vcf.gz
# [2026-01-09 01:20:20] VCF compressed successfully
# [2026-01-09 01:20:20] Indexing VCF file...
# [2026-01-09 01:20:20] Running: VCF indexing
# [2026-01-09 01:20:20] Command: tabix -p vcf /workspace/datasets/haploid/vcf/STR134.high_confidence.vcf.gz
# [2026-01-09 01:20:20]
# Number of variants in VCF: 102
# [2026-01-09 01:20:20] Applying variants to reference...
# [2026-01-09 01:20:20] bcftools stderr: Note: the --sample option not given, applying all records regardless of the genotype
# Applied 102 variants
#
# [2026-01-09 01:20:20]
# ============================================================
# [2026-01-09 01:20:20] VALIDATION REPORT
# [2026-01-09 01:20:20] ============================================================
# [2026-01-09 01:20:20]
# Input FASTA statistics:
# [2026-01-09 01:20:20]   Number of sequences: 6
# [2026-01-09 01:20:20]   Total length: 9,424,047 bp
# [2026-01-09 01:20:20]   MD5 checksum: b9cee39a8f09442812e931e696db77f2
# [2026-01-09 01:20:20]
# Output FASTA statistics:
# [2026-01-09 01:20:20]   Number of sequences: 6
# [2026-01-09 01:20:20]   Total length: 9,424,056 bp
# [2026-01-09 01:20:20]   MD5 checksum: 0979ba43a6bcf959350e3011f3b25a88
# [2026-01-09 01:20:20]
# Validation checks:
# [2026-01-09 01:20:20]   ✓ Number of sequences matches
# [2026-01-09 01:20:20]   ✓ Output differs from input (variants applied)
# [2026-01-09 01:20:20]   ✓ Output file exists and has content
# [2026-01-09 01:20:20]
#   Length change: +9 bp
# [2026-01-09 01:20:20]
# ============================================================
# [2026-01-09 01:20:20] ✓ VALIDATION PASSED
# [2026-01-09 01:20:20] ============================================================
#
# [2026-01-09 01:20:20]
# Pipeline completed successfully!
# [2026-01-09 01:20:20] Output saved to: /workspace/datasets/haploid/fasta/STR134.fasta
# [2026-01-09 01:20:20] ============================================================
# [2026-01-09 01:20:20] VCF to FASTA Pipeline
# [2026-01-09 01:20:20] ============================================================
# [2026-01-09 01:20:20] Input FASTA: /workspace/datasets/haploid/fasta/04245.denovo.fasta
# [2026-01-09 01:20:20] Input VCF: /workspace/datasets/haploid/vcf/STR267.high_confidence.vcf
# [2026-01-09 01:20:20] Output FASTA: /workspace/datasets/haploid/fasta/STR267.fasta
# [2026-01-09 01:20:20] Log file: /workspace/datasets/haploid/logs/STR267.vcftofasta.pipeline.log
# [2026-01-09 01:20:20] ============================================================
#
# [2026-01-09 01:20:20] Checking dependencies...
# [2026-01-09 01:20:20] ✓ bcftools found
# [2026-01-09 01:20:20] ✓ samtools found
# [2026-01-09 01:20:20] ✓ bgzip found
# [2026-01-09 01:20:20] ✓ tabix found
# [2026-01-09 01:20:20] FASTA index already exists: /workspace/datasets/haploid/fasta/04245.denovo.fasta.fai
# [2026-01-09 01:20:20] Compressing VCF file...
# [2026-01-09 01:20:20] Command: bgzip -c /workspace/datasets/haploid/vcf/STR267.high_confidence.vcf > /workspace/datasets/haploid/vcf/STR267.high_confidence.vcf.gz
# [2026-01-09 01:20:20] VCF compressed successfully
# [2026-01-09 01:20:20] Indexing VCF file...
# [2026-01-09 01:20:20] Running: VCF indexing
# [2026-01-09 01:20:20] Command: tabix -p vcf /workspace/datasets/haploid/vcf/STR267.high_confidence.vcf.gz
# [2026-01-09 01:20:20]
# Number of variants in VCF: 109
# [2026-01-09 01:20:20] Applying variants to reference...
# [2026-01-09 01:20:20] bcftools stderr: Note: the --sample option not given, applying all records regardless of the genotype
# Applied 109 variants
#
# [2026-01-09 01:20:20]
# ============================================================
# [2026-01-09 01:20:20] VALIDATION REPORT
# [2026-01-09 01:20:20] ============================================================
# [2026-01-09 01:20:20]
# Input FASTA statistics:
# [2026-01-09 01:20:20]   Number of sequences: 6
# [2026-01-09 01:20:20]   Total length: 9,424,047 bp
# [2026-01-09 01:20:20]   MD5 checksum: b9cee39a8f09442812e931e696db77f2
# [2026-01-09 01:20:20]
# Output FASTA statistics:
# [2026-01-09 01:20:20]   Number of sequences: 6
# [2026-01-09 01:20:20]   Total length: 9,424,115 bp
# [2026-01-09 01:20:20]   MD5 checksum: e8bc1ff4687e0a35f1c8f0d7457de018
# [2026-01-09 01:20:20]
# Validation checks:
# [2026-01-09 01:20:20]   ✓ Number of sequences matches
# [2026-01-09 01:20:20]   ✓ Output differs from input (variants applied)
# [2026-01-09 01:20:20]   ✓ Output file exists and has content
# [2026-01-09 01:20:20]
#   Length change: +68 bp
# [2026-01-09 01:20:20]
# ============================================================
# [2026-01-09 01:20:20] ✓ VALIDATION PASSED
# [2026-01-09 01:20:20] ============================================================
#
# [2026-01-09 01:20:20]
# Pipeline completed successfully!
# [2026-01-09 01:20:20] Output saved to: /workspace/datasets/haploid/fasta/STR267.fasta
# [2026-01-09 01:20:20] ============================================================
# [2026-01-09 01:20:20] VCF to FASTA Pipeline
# [2026-01-09 01:20:20] ============================================================
# [2026-01-09 01:20:20] Input FASTA: /workspace/datasets/haploid/fasta/04245.denovo.fasta
# [2026-01-09 01:20:20] Input VCF: /workspace/datasets/haploid/vcf/STR286.high_confidence.vcf
# [2026-01-09 01:20:20] Output FASTA: /workspace/datasets/haploid/fasta/STR286.fasta
# [2026-01-09 01:20:20] Log file: /workspace/datasets/haploid/logs/STR286.vcftofasta.pipeline.log
# [2026-01-09 01:20:20] ============================================================
#
# [2026-01-09 01:20:20] Checking dependencies...
# [2026-01-09 01:20:20] ✓ bcftools found
# [2026-01-09 01:20:20] ✓ samtools found
# [2026-01-09 01:20:20] ✓ bgzip found
# [2026-01-09 01:20:20] ✓ tabix found
# [2026-01-09 01:20:20] FASTA index already exists: /workspace/datasets/haploid/fasta/04245.denovo.fasta.fai
# [2026-01-09 01:20:20] Compressing VCF file...
# [2026-01-09 01:20:20] Command: bgzip -c /workspace/datasets/haploid/vcf/STR286.high_confidence.vcf > /workspace/datasets/haploid/vcf/STR286.high_confidence.vcf.gz
# [2026-01-09 01:20:20] VCF compressed successfully
# [2026-01-09 01:20:20] Indexing VCF file...
# [2026-01-09 01:20:20] Running: VCF indexing
# [2026-01-09 01:20:20] Command: tabix -p vcf /workspace/datasets/haploid/vcf/STR286.high_confidence.vcf.gz
# [2026-01-09 01:20:20]
# Number of variants in VCF: 35
# [2026-01-09 01:20:20] Applying variants to reference...
# [2026-01-09 01:20:20] bcftools stderr: Note: the --sample option not given, applying all records regardless of the genotype
# Applied 35 variants
#
# [2026-01-09 01:20:20]
# ============================================================
# [2026-01-09 01:20:20] VALIDATION REPORT
# [2026-01-09 01:20:20] ============================================================
# [2026-01-09 01:20:20]
# Input FASTA statistics:
# [2026-01-09 01:20:20]   Number of sequences: 6
# [2026-01-09 01:20:20]   Total length: 9,424,047 bp
# [2026-01-09 01:20:20]   MD5 checksum: b9cee39a8f09442812e931e696db77f2
# [2026-01-09 01:20:20]
# Output FASTA statistics:
# [2026-01-09 01:20:18]   Number of sequences: 6
# [2026-01-09 01:20:18]   Total length: 9,424,056 bp
# [2026-01-09 01:20:18]   MD5 checksum: 86cfda243bf0530abe324cf4b76afc9c
# [2026-01-09 01:20:18]
# Validation checks:
# [2026-01-09 01:20:18]   ✓ Number of sequences matches
# [2026-01-09 01:20:18]   ✓ Output differs from input (variants applied)
# [2026-01-09 01:20:18]   ✓ Output file exists and has content
# [2026-01-09 01:20:18]
#   Length change: +9 bp
# [2026-01-09 01:20:18]
# ============================================================
# [2026-01-09 01:20:18] ✓ VALIDATION PASSED
# [2026-01-09 01:20:18] ============================================================
#
# [2026-01-09 01:20:18]
# Pipeline completed successfully!
# [2026-01-09 01:20:18] Output saved to: /workspace/datasets/haploid/fasta/STR286.fasta
